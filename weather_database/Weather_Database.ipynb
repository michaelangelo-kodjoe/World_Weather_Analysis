# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
from config import weather_api_key
import requests
import time
from datetime import datetime

# %%
# Getting random Latitudes and Longitudes
lat = np.random.uniform(-90,90, size= 2000)
lng = np.random.uniform(-180,180, size= 2000)
lat_lng = zip(lat,lng)

# %%
# Adding URL Link
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Craeate a list of coordinates from the zip file
coordinates = list(lat_lng)

# %%
# Create an empty list to hold all the city data
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # Put each unique city in found in the cities list
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,                          
                          "Date": city_date})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | norman wells
# Processing Record 2 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 1 | aklavik
# Processing Record 4 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | lasa
# Processing Record 7 of Set 1 | burnie
# Processing Record 8 of Set 1 | kahului
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | kousseri
# Processing Record 17 of Set 1 | dombarovskiy
# Processing Record 18 of Set 1 | punta alta
# Processing Record 19 of Set 1 | anahuac
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | nabire
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | goderich
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | makasar
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | jackson
# Processing Record 35 of Set 1 | gravdal
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | hofn
# Processing Record 39 of Set 1 | tabou
# Processing Record 40 of Set 1 | santa rosa
# Processing Record 41 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | lopsmarka
# Processing Record 45 of Set 1 | paucartambo
# City not found. Skipping...
# Processing Record 46 of Set 1 | mingguang
# Processing Record 47 of Set 1 | pevek
# Processing Record 48 of Set 1 | port hedland
# Processing Record 49 of Set 1 | tsiroanomandidy
# Processing Record 50 of Set 1 | fairbanks
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | acapulco
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | zhaotong
# Processing Record 9 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | mayumba
# Processing Record 11 of Set 2 | kuching
# Processing Record 12 of Set 2 | guilin
# Processing Record 13 of Set 2 | palu
# Processing Record 14 of Set 2 | padang
# Processing Record 15 of Set 2 | poum
# Processing Record 16 of Set 2 | salalah
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | saldanha
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | alta
# Processing Record 21 of Set 2 | hay river
# Processing Record 22 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 2 | souillac
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | champerico
# Processing Record 26 of Set 2 | upernavik
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | sept-iles
# Processing Record 31 of Set 2 | san juan
# Processing Record 32 of Set 2 | svetlyy
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | zhigansk
# Processing Record 35 of Set 2 | caraballeda
# Processing Record 36 of Set 2 | sisimiut
# Processing Record 37 of Set 2 | sao jose da coroa grande
# Processing Record 38 of Set 2 | buala
# Processing Record 39 of Set 2 | fatehabad
# Processing Record 40 of Set 2 | krasnyy oktyabr
# Processing Record 41 of Set 2 | chibuto
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | qovlar
# Processing Record 44 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 2 | rafraf
# Processing Record 46 of Set 2 | praia
# Processing Record 47 of Set 2 | yantarnyy
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | miyako
# Processing Record 50 of Set 2 | katsiveli
# City not found. Skipping...
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 3 of Set 3 | marsh harbour
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | koslan
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | launceston
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | carballo
# Processing Record 10 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 3 | maniitsoq
# Processing Record 12 of Set 3 | san carlos de bariloche
# Processing Record 13 of Set 3 | hiriyur
# Processing Record 14 of Set 3 | chumikan
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | umea
# Processing Record 17 of Set 3 | cockburn town
# Processing Record 18 of Set 3 | lumphat
# Processing Record 19 of Set 3 | sorong
# Processing Record 20 of Set 3 | feni
# Processing Record 21 of Set 3 | atuona
# Processing Record 22 of Set 3 | almas
# Processing Record 23 of Set 3 | umm jarr
# City not found. Skipping...
# Processing Record 24 of Set 3 | chuy
# Processing Record 25 of Set 3 | tingi
# Processing Record 26 of Set 3 | alofi
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | hualmay
# Processing Record 29 of Set 3 | maarianhamina
# Processing Record 30 of Set 3 | yeppoon
# Processing Record 31 of Set 3 | ribeira grande
# Processing Record 32 of Set 3 | tezu
# Processing Record 33 of Set 3 | sola
# Processing Record 34 of Set 3 | muros
# Processing Record 35 of Set 3 | barrow
# Processing Record 36 of Set 3 | broken hill
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | villablino
# Processing Record 39 of Set 3 | san fernando
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | peniche
# Processing Record 42 of Set 3 | port hardy
# Processing Record 43 of Set 3 | cabedelo
# Processing Record 44 of Set 3 | tokur
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | duku
# Processing Record 49 of Set 3 | san cristobal
# Processing Record 50 of Set 3 | tambura
# Processing Record 1 of Set 4 | westport
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | nantucket
# Processing Record 4 of Set 4 | baiao
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | seddon
# Processing Record 7 of Set 4 | paracatu
# Processing Record 8 of Set 4 | bilibino
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | mahebourg
# Processing Record 11 of Set 4 | fare
# Processing Record 12 of Set 4 | caravelas
# Processing Record 13 of Set 4 | fomboni
# Processing Record 14 of Set 4 | monte alegre
# Processing Record 15 of Set 4 | sehithwa
# Processing Record 16 of Set 4 | mabama
# Processing Record 17 of Set 4 | amurzet
# Processing Record 18 of Set 4 | tabuk
# Processing Record 19 of Set 4 | bongandanga
# Processing Record 20 of Set 4 | mgandu
# Processing Record 21 of Set 4 | leh
# Processing Record 22 of Set 4 | harper
# Processing Record 23 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 4 | amapa
# Processing Record 25 of Set 4 | lompoc
# Processing Record 26 of Set 4 | krasnokamensk
# Processing Record 27 of Set 4 | bykovo
# Processing Record 28 of Set 4 | kushmurun
# Processing Record 29 of Set 4 | caledon
# Processing Record 30 of Set 4 | bubaque
# Processing Record 31 of Set 4 | bria
# Processing Record 32 of Set 4 | gull lake
# Processing Record 33 of Set 4 | kavieng
# Processing Record 34 of Set 4 | menongue
# Processing Record 35 of Set 4 | manaure
# Processing Record 36 of Set 4 | bardsir
# Processing Record 37 of Set 4 | halifax
# Processing Record 38 of Set 4 | thompson
# Processing Record 39 of Set 4 | iwanai
# Processing Record 40 of Set 4 | nadym
# Processing Record 41 of Set 4 | chilmari
# Processing Record 42 of Set 4 | tiarei
# Processing Record 43 of Set 4 | male
# Processing Record 44 of Set 4 | grindavik
# Processing Record 45 of Set 4 | waki
# Processing Record 46 of Set 4 | khatanga
# Processing Record 47 of Set 4 | mogapinyana
# Processing Record 48 of Set 4 | seoul
# Processing Record 49 of Set 4 | vysokopillya
# Processing Record 50 of Set 4 | lebu
# Processing Record 1 of Set 5 | karratha
# Processing Record 2 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 5 | kamenka
# Processing Record 4 of Set 5 | haines junction
# Processing Record 5 of Set 5 | okato
# Processing Record 6 of Set 5 | xuanhua
# Processing Record 7 of Set 5 | dillon
# Processing Record 8 of Set 5 | ilhabela
# Processing Record 9 of Set 5 | lagoa
# Processing Record 10 of Set 5 | hilo
# Processing Record 11 of Set 5 | banda aceh
# Processing Record 12 of Set 5 | rapid city
# Processing Record 13 of Set 5 | libertador general san martin
# Processing Record 14 of Set 5 | waingapu
# Processing Record 15 of Set 5 | port elizabeth
# Processing Record 16 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 17 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 5 | morro bay
# Processing Record 19 of Set 5 | waddan
# Processing Record 20 of Set 5 | gaya
# Processing Record 21 of Set 5 | mandalgovi
# Processing Record 22 of Set 5 | porto walter
# Processing Record 23 of Set 5 | nueva concepcion
# Processing Record 24 of Set 5 | bambanglipuro
# Processing Record 25 of Set 5 | balykshi
# Processing Record 26 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 5 | port lincoln
# Processing Record 28 of Set 5 | sovetskiy
# Processing Record 29 of Set 5 | talnakh
# Processing Record 30 of Set 5 | pangnirtung
# Processing Record 31 of Set 5 | malakal
# Processing Record 32 of Set 5 | healdsburg
# Processing Record 33 of Set 5 | puerto escondido
# Processing Record 34 of Set 5 | solginskiy
# Processing Record 35 of Set 5 | wuwei
# Processing Record 36 of Set 5 | middelburg
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | black river
# Processing Record 39 of Set 5 | mount gambier
# Processing Record 40 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 5 | port blair
# Processing Record 42 of Set 5 | saint-francois
# Processing Record 43 of Set 5 | seka
# Processing Record 44 of Set 5 | mandera
# Processing Record 45 of Set 5 | buenos aires
# Processing Record 46 of Set 5 | cururupu
# Processing Record 47 of Set 5 | yar-sale
# Processing Record 48 of Set 5 | samatau
# City not found. Skipping...
# Processing Record 49 of Set 5 | adrar
# Processing Record 50 of Set 5 | otradnoye
# Processing Record 1 of Set 6 | chake chake
# Processing Record 2 of Set 6 | najran
# Processing Record 3 of Set 6 | darhan
# Processing Record 4 of Set 6 | fortuna
# Processing Record 5 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 6 | srirampur
# Processing Record 8 of Set 6 | rio gallegos
# Processing Record 9 of Set 6 | anamur
# Processing Record 10 of Set 6 | severo-kurilsk
# Processing Record 11 of Set 6 | bereda
# Processing Record 12 of Set 6 | saskylakh
# Processing Record 13 of Set 6 | provideniya
# Processing Record 14 of Set 6 | mangulile
# Processing Record 15 of Set 6 | aksarka
# Processing Record 16 of Set 6 | homestead
# Processing Record 17 of Set 6 | olafsvik
# Processing Record 18 of Set 6 | georgetown
# Processing Record 19 of Set 6 | tatarsk
# Processing Record 20 of Set 6 | ostrovnoy
# Processing Record 21 of Set 6 | hirara
# Processing Record 22 of Set 6 | comodoro rivadavia
# Processing Record 23 of Set 6 | morogoro
# Processing Record 24 of Set 6 | el carmen
# Processing Record 25 of Set 6 | hithadhoo
# Processing Record 26 of Set 6 | cayenne
# Processing Record 27 of Set 6 | kishni
# Processing Record 28 of Set 6 | carutapera
# Processing Record 29 of Set 6 | lukovetskiy
# Processing Record 30 of Set 6 | butte
# Processing Record 31 of Set 6 | dinghai
# Processing Record 32 of Set 6 | kegums
# Processing Record 33 of Set 6 | oranjemund
# Processing Record 34 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 35 of Set 6 | vanimo
# Processing Record 36 of Set 6 | hudson bay
# Processing Record 37 of Set 6 | krasnyy chikoy
# Processing Record 38 of Set 6 | almaznyy
# Processing Record 39 of Set 6 | iracoubo
# Processing Record 40 of Set 6 | kargopol
# Processing Record 41 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 6 | bethel
# Processing Record 43 of Set 6 | randudongkal
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | zaria
# Processing Record 46 of Set 6 | hammerfest
# Processing Record 47 of Set 6 | kodinsk
# Processing Record 48 of Set 6 | kardamaina
# Processing Record 49 of Set 6 | prince rupert
# Processing Record 50 of Set 6 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 1 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 7 | kieta
# Processing Record 3 of Set 7 | pavino
# Processing Record 4 of Set 7 | porto novo
# Processing Record 5 of Set 7 | ambilobe
# Processing Record 6 of Set 7 | kidodi
# Processing Record 7 of Set 7 | chute-aux-outardes
# Processing Record 8 of Set 7 | asau
# Processing Record 9 of Set 7 | port-gentil
# Processing Record 10 of Set 7 | deputatskiy
# Processing Record 11 of Set 7 | springbok
# Processing Record 12 of Set 7 | torbay
# Processing Record 13 of Set 7 | acari
# Processing Record 14 of Set 7 | sakaiminato
# Processing Record 15 of Set 7 | baniyas
# Processing Record 16 of Set 7 | lahij
# Processing Record 17 of Set 7 | abong mbang
# Processing Record 18 of Set 7 | vestmannaeyjar
# Processing Record 19 of Set 7 | dawei
# Processing Record 20 of Set 7 | sechura
# Processing Record 21 of Set 7 | bagdarin
# Processing Record 22 of Set 7 | narasannapeta
# Processing Record 23 of Set 7 | gat
# Processing Record 24 of Set 7 | saint-joseph
# Processing Record 25 of Set 7 | marzuq
# Processing Record 26 of Set 7 | heihe
# Processing Record 27 of Set 7 | te anau
# Processing Record 28 of Set 7 | copiapo
# Processing Record 29 of Set 7 | sinnamary
# Processing Record 30 of Set 7 | ngunguru
# Processing Record 31 of Set 7 | saint marys
# Processing Record 32 of Set 7 | richards bay
# Processing Record 33 of Set 7 | conceicao do araguaia
# Processing Record 34 of Set 7 | leshukonskoye
# Processing Record 35 of Set 7 | camana
# Processing Record 36 of Set 7 | nyurba
# Processing Record 37 of Set 7 | kemijarvi
# Processing Record 38 of Set 7 | antofagasta
# Processing Record 39 of Set 7 | tuatapere
# Processing Record 40 of Set 7 | half moon bay
# Processing Record 41 of Set 7 | vrangel
# Processing Record 42 of Set 7 | jibuti
# Processing Record 43 of Set 7 | llanes
# Processing Record 44 of Set 7 | sabaudia
# Processing Record 45 of Set 7 | crateus
# Processing Record 46 of Set 7 | krechevitsy
# Processing Record 47 of Set 7 | ahipara
# Processing Record 48 of Set 7 | morgan city
# Processing Record 49 of Set 7 | labuan
# Processing Record 50 of Set 7 | alice springs
# Processing Record 1 of Set 8 | weilheim
# Processing Record 2 of Set 8 | gujar khan
# Processing Record 3 of Set 8 | sobolevo
# Processing Record 4 of Set 8 | luderitz
# Processing Record 5 of Set 8 | brenham
# Processing Record 6 of Set 8 | debre birhan
# Processing Record 7 of Set 8 | kavaratti
# Processing Record 8 of Set 8 | conway
# Processing Record 9 of Set 8 | awbari
# Processing Record 10 of Set 8 | huilong
# Processing Record 11 of Set 8 | xam nua
# Processing Record 12 of Set 8 | ischia
# Processing Record 13 of Set 8 | noumea
# Processing Record 14 of Set 8 | mouzakion
# City not found. Skipping...
# Processing Record 15 of Set 8 | kaitangata
# Processing Record 16 of Set 8 | arraial do cabo
# Processing Record 17 of Set 8 | geraldton
# Processing Record 18 of Set 8 | labuhan
# Processing Record 19 of Set 8 | sungaipenuh
# Processing Record 20 of Set 8 | lesogorsk
# Processing Record 21 of Set 8 | husavik
# Processing Record 22 of Set 8 | stromness
# Processing Record 23 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 8 | callaway
# Processing Record 25 of Set 8 | terney
# Processing Record 26 of Set 8 | kokopo
# Processing Record 27 of Set 8 | shengjin
# Processing Record 28 of Set 8 | caronport
# Processing Record 29 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 30 of Set 8 | pudozh
# Processing Record 31 of Set 8 | caohai
# Processing Record 32 of Set 8 | junagarh
# Processing Record 33 of Set 8 | soissons
# Processing Record 34 of Set 8 | kinablangan
# Processing Record 35 of Set 8 | quata
# Processing Record 36 of Set 8 | nanjing
# Processing Record 37 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 8 | singkawang
# Processing Record 39 of Set 8 | nevinnomyssk
# Processing Record 40 of Set 8 | kruisfontein
# Processing Record 41 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 42 of Set 8 | sampit
# Processing Record 43 of Set 8 | flinders
# Processing Record 44 of Set 8 | mareeba
# Processing Record 45 of Set 8 | ayan
# Processing Record 46 of Set 8 | turbat
# Processing Record 47 of Set 8 | manaus
# Processing Record 48 of Set 8 | smithers
# Processing Record 49 of Set 8 | ratnagiri
# Processing Record 50 of Set 8 | srednekolymsk
# Processing Record 1 of Set 9 | fiumicino
# Processing Record 2 of Set 9 | lakatoro
# Processing Record 3 of Set 9 | quang ngai
# Processing Record 4 of Set 9 | vanino
# Processing Record 5 of Set 9 | namibe
# Processing Record 6 of Set 9 | montepuez
# Processing Record 7 of Set 9 | pocone
# Processing Record 8 of Set 9 | paranhos
# Processing Record 9 of Set 9 | ormara
# Processing Record 10 of Set 9 | chapleau
# Processing Record 11 of Set 9 | san buenaventura
# Processing Record 12 of Set 9 | pemangkat
# Processing Record 13 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 9 | pravia
# Processing Record 15 of Set 9 | trairi
# Processing Record 16 of Set 9 | fort-shevchenko
# Processing Record 17 of Set 9 | los llanos de aridane
# Processing Record 18 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 9 | zhifang
# Processing Record 20 of Set 9 | saint anthony
# Processing Record 21 of Set 9 | victoria
# Processing Record 22 of Set 9 | naliya
# Processing Record 23 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 24 of Set 9 | oranjestad
# Processing Record 25 of Set 9 | codrington
# Processing Record 26 of Set 9 | leleasca
# Processing Record 27 of Set 9 | charters towers
# Processing Record 28 of Set 9 | yopal
# Processing Record 29 of Set 9 | stamsund
# City not found. Skipping...
# Processing Record 30 of Set 9 | ferme-neuve
# Processing Record 31 of Set 9 | burica
# City not found. Skipping...
# Processing Record 32 of Set 9 | nguruka
# Processing Record 33 of Set 9 | thinadhoo
# Processing Record 34 of Set 9 | dingle
# Processing Record 35 of Set 9 | kidal
# Processing Record 36 of Set 9 | wattegama
# Processing Record 37 of Set 9 | chirongui
# Processing Record 38 of Set 9 | ust-nera
# Processing Record 39 of Set 9 | inzer
# Processing Record 40 of Set 9 | hawera
# Processing Record 41 of Set 9 | morondava
# Processing Record 42 of Set 9 | satka
# Processing Record 43 of Set 9 | plettenberg bay
# Processing Record 44 of Set 9 | isangel
# Processing Record 45 of Set 9 | khandyga
# Processing Record 46 of Set 9 | vestmanna
# Processing Record 47 of Set 9 | maragogi
# Processing Record 48 of Set 9 | pitea
# Processing Record 49 of Set 9 | basco
# Processing Record 50 of Set 9 | lumeje
# Processing Record 1 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 10 | vardo
# Processing Record 3 of Set 10 | bud
# Processing Record 4 of Set 10 | imbituba
# Processing Record 5 of Set 10 | maple creek
# Processing Record 6 of Set 10 | quepos
# Processing Record 7 of Set 10 | yumen
# Processing Record 8 of Set 10 | tura
# Processing Record 9 of Set 10 | naqadeh
# Processing Record 10 of Set 10 | pochutla
# Processing Record 11 of Set 10 | moen
# Processing Record 12 of Set 10 | mana
# Processing Record 13 of Set 10 | voh
# Processing Record 14 of Set 10 | nelson bay
# Processing Record 15 of Set 10 | yulara
# Processing Record 16 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 17 of Set 10 | korla
# Processing Record 18 of Set 10 | baft
# Processing Record 19 of Set 10 | anadyr
# Processing Record 20 of Set 10 | panubigan
# Processing Record 21 of Set 10 | mindelo
# Processing Record 22 of Set 10 | vonyarcvashegy
# Processing Record 23 of Set 10 | derzhavinsk
# Processing Record 24 of Set 10 | gaoua
# Processing Record 25 of Set 10 | antalaha
# Processing Record 26 of Set 10 | chutung
# City not found. Skipping...
# Processing Record 27 of Set 10 | zapolyarnyy
# Processing Record 28 of Set 10 | naze
# Processing Record 29 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 30 of Set 10 | juquia
# Processing Record 31 of Set 10 | nayoro
# Processing Record 32 of Set 10 | esperance
# Processing Record 33 of Set 10 | kuytun
# Processing Record 34 of Set 10 | abatskoye
# Processing Record 35 of Set 10 | jian
# Processing Record 36 of Set 10 | muromtsevo
# Processing Record 37 of Set 10 | san juan de los morros
# Processing Record 38 of Set 10 | khandagayty
# Processing Record 39 of Set 10 | tazovskiy
# Processing Record 40 of Set 10 | priladozhskiy
# Processing Record 41 of Set 10 | tomatlan
# Processing Record 42 of Set 10 | ivankiv
# Processing Record 43 of Set 10 | waipawa
# Processing Record 44 of Set 10 | kampot
# Processing Record 45 of Set 10 | katsuura
# Processing Record 46 of Set 10 | concordia
# Processing Record 47 of Set 10 | medford
# Processing Record 48 of Set 10 | capreol
# Processing Record 49 of Set 10 | rauma
# Processing Record 50 of Set 10 | kensington
# Processing Record 1 of Set 11 | pontarlier
# Processing Record 2 of Set 11 | namatanai
# Processing Record 3 of Set 11 | saint-pierre
# Processing Record 4 of Set 11 | rocha
# Processing Record 5 of Set 11 | itarema
# Processing Record 6 of Set 11 | bonavista
# Processing Record 7 of Set 11 | boa vista
# Processing Record 8 of Set 11 | inhambane
# Processing Record 9 of Set 11 | general roca
# Processing Record 10 of Set 11 | gogrial
# Processing Record 11 of Set 11 | alugan
# Processing Record 12 of Set 11 | guerrero negro
# Processing Record 13 of Set 11 | farim
# Processing Record 14 of Set 11 | araouane
# Processing Record 15 of Set 11 | bandarbeyla
# Processing Record 16 of Set 11 | banyo
# Processing Record 17 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 11 | alpine
# Processing Record 19 of Set 11 | jalu
# Processing Record 20 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 11 | newport
# Processing Record 22 of Set 11 | eureka
# Processing Record 23 of Set 11 | machico
# Processing Record 24 of Set 11 | ho
# City not found. Skipping...
# Processing Record 25 of Set 11 | poso
# Processing Record 26 of Set 11 | ahuimanu
# Processing Record 27 of Set 11 | wamba
# Processing Record 28 of Set 11 | bengkulu
# Processing Record 29 of Set 11 | kosh-agach
# Processing Record 30 of Set 11 | bonnyville
# Processing Record 31 of Set 11 | lethem
# Processing Record 32 of Set 11 | aksu
# Processing Record 33 of Set 11 | nome
# Processing Record 34 of Set 11 | bend
# Processing Record 35 of Set 11 | beloha
# Processing Record 36 of Set 11 | binga
# Processing Record 37 of Set 11 | catmondaan
# Processing Record 38 of Set 11 | port keats
# Processing Record 39 of Set 11 | omboue
# Processing Record 40 of Set 11 | otavi
# Processing Record 41 of Set 11 | mahajanga
# Processing Record 42 of Set 11 | aguimes
# Processing Record 43 of Set 11 | dorokhovo
# Processing Record 44 of Set 11 | palana
# Processing Record 45 of Set 11 | kitgum
# Processing Record 46 of Set 11 | iqaluit
# Processing Record 47 of Set 11 | marystown
# Processing Record 48 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 49 of Set 11 | la ligua
# Processing Record 50 of Set 11 | listvyanskiy
# Processing Record 1 of Set 12 | vysokogornyy
# Processing Record 2 of Set 12 | kozhevnikovo
# Processing Record 3 of Set 12 | urumqi
# Processing Record 4 of Set 12 | klaksvik
# Processing Record 5 of Set 12 | langxiang
# Processing Record 6 of Set 12 | ugoofaaru
# Processing Record 7 of Set 12 | solnechnyy
# Processing Record 8 of Set 12 | egvekinot
# Processing Record 9 of Set 12 | yerofey pavlovich
# Processing Record 10 of Set 12 | chekhov
# Processing Record 11 of Set 12 | glendive
# Processing Record 12 of Set 12 | ixtapa
# Processing Record 13 of Set 12 | bantou
# Processing Record 14 of Set 12 | roebourne
# Processing Record 15 of Set 12 | cobija
# Processing Record 16 of Set 12 | bathsheba
# Processing Record 17 of Set 12 | barranca de upia
# Processing Record 18 of Set 12 | ballitoville
# Processing Record 19 of Set 12 | rameswaram
# Processing Record 20 of Set 12 | nampula
# Processing Record 21 of Set 12 | srandakan
# Processing Record 22 of Set 12 | kenai
# Processing Record 23 of Set 12 | jaca
# Processing Record 24 of Set 12 | adana
# Processing Record 25 of Set 12 | viedma
# Processing Record 26 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 12 | tegh
# Processing Record 28 of Set 12 | tocopilla
# Processing Record 29 of Set 12 | madimba
# Processing Record 30 of Set 12 | sur
# Processing Record 31 of Set 12 | zhangye
# Processing Record 32 of Set 12 | cervo
# Processing Record 33 of Set 12 | yuli
# Processing Record 34 of Set 12 | caconda
# Processing Record 35 of Set 12 | quatre cocos
# Processing Record 36 of Set 12 | conde
# Processing Record 37 of Set 12 | ninghai
# Processing Record 38 of Set 12 | yertsevo
# Processing Record 39 of Set 12 | tessalit
# Processing Record 40 of Set 12 | lukang
# Processing Record 41 of Set 12 | kavos
# Processing Record 42 of Set 12 | kulachi
# Processing Record 43 of Set 12 | aripuana
# Processing Record 44 of Set 12 | tautira
# Processing Record 45 of Set 12 | valley city
# Processing Record 46 of Set 12 | mayor pablo lagerenza
# Processing Record 47 of Set 12 | castro
# Processing Record 48 of Set 12 | acarau
# Processing Record 49 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 50 of Set 12 | skala fourkas
# Processing Record 1 of Set 13 | roma
# Processing Record 2 of Set 13 | touros
# Processing Record 3 of Set 13 | agirish
# Processing Record 4 of Set 13 | ust-tsilma
# Processing Record 5 of Set 13 | san joaquin
# Processing Record 6 of Set 13 | wum
# Processing Record 7 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 13 | puerto montt
# Processing Record 9 of Set 13 | thessalon
# Processing Record 10 of Set 13 | gasa
# Processing Record 11 of Set 13 | castro alves
# Processing Record 12 of Set 13 | shubarkuduk
# Processing Record 13 of Set 13 | nangomba
# Processing Record 14 of Set 13 | puerto ayacucho
# Processing Record 15 of Set 13 | kadnikov
# Processing Record 16 of Set 13 | belyy yar
# Processing Record 17 of Set 13 | faya
# Processing Record 18 of Set 13 | guapo
# Processing Record 19 of Set 13 | puri
# Processing Record 20 of Set 13 | shelburne
# Processing Record 21 of Set 13 | ca mau
# Processing Record 22 of Set 13 | arlit
# Processing Record 23 of Set 13 | orlik
# Processing Record 24 of Set 13 | beringovskiy
# Processing Record 25 of Set 13 | polovinnoye
# Processing Record 26 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 13 | kirakira
# Processing Record 28 of Set 13 | sorland
# Processing Record 29 of Set 13 | trat
# Processing Record 30 of Set 13 | zhezkazgan
# Processing Record 31 of Set 13 | cochrane
# Processing Record 32 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 13 | grand-lahou
# Processing Record 34 of Set 13 | zeya
# Processing Record 35 of Set 13 | murgab
# Processing Record 36 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 13 | axim
# Processing Record 38 of Set 13 | alpena
# Processing Record 39 of Set 13 | rottenmann
# Processing Record 40 of Set 13 | spokane
# Processing Record 41 of Set 13 | umm lajj
# Processing Record 42 of Set 13 | mokhsogollokh
# Processing Record 43 of Set 13 | gweta
# Processing Record 44 of Set 13 | voi
# Processing Record 45 of Set 13 | clyde river
# Processing Record 46 of Set 13 | sahuaripa
# Processing Record 47 of Set 13 | mehamn
# Processing Record 48 of Set 13 | takoradi
# Processing Record 49 of Set 13 | tigil
# Processing Record 50 of Set 13 | beidao
# Processing Record 1 of Set 14 | baryatino
# Processing Record 2 of Set 14 | collie
# Processing Record 3 of Set 14 | kismayo
# Processing Record 4 of Set 14 | nauta
# Processing Record 5 of Set 14 | asbe teferi
# Processing Record 6 of Set 14 | san javier
# Processing Record 7 of Set 14 | havre-saint-pierre
# Processing Record 8 of Set 14 | chicama
# Processing Record 9 of Set 14 | inuvik
# Processing Record 10 of Set 14 | pitimbu
# Processing Record 11 of Set 14 | la paz
# Processing Record 12 of Set 14 | mercedes
# Processing Record 13 of Set 14 | kitimat
# Processing Record 14 of Set 14 | natal
# Processing Record 15 of Set 14 | pacific grove
# Processing Record 16 of Set 14 | merauke
# Processing Record 17 of Set 14 | idlib
# Processing Record 18 of Set 14 | callaguip
# Processing Record 19 of Set 14 | fort nelson
# Processing Record 20 of Set 14 | sitka
# Processing Record 21 of Set 14 | reconquista
# Processing Record 22 of Set 14 | takaka
# Processing Record 23 of Set 14 | aloleng
# Processing Record 24 of Set 14 | jutai
# Processing Record 25 of Set 14 | medina del campo
# Processing Record 26 of Set 14 | sestri levante
# Processing Record 27 of Set 14 | krutikha
# Processing Record 28 of Set 14 | loreto
# Processing Record 29 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 30 of Set 14 | baturite
# Processing Record 31 of Set 14 | kupang
# Processing Record 32 of Set 14 | havre
# Processing Record 33 of Set 14 | kenora
# Processing Record 34 of Set 14 | catuday
# Processing Record 35 of Set 14 | wenchi
# Processing Record 36 of Set 14 | mahbubabad
# Processing Record 37 of Set 14 | barstow
# Processing Record 38 of Set 14 | kajaani
# Processing Record 39 of Set 14 | omihachiman
# Processing Record 40 of Set 14 | shar
# Processing Record 41 of Set 14 | zaranj
# Processing Record 42 of Set 14 | paramonga
# Processing Record 43 of Set 14 | panama city
# Processing Record 44 of Set 14 | shitkino
# Processing Record 45 of Set 14 | itaqui
# Processing Record 46 of Set 14 | searcy
# Processing Record 47 of Set 14 | ilulissat
# Processing Record 48 of Set 14 | kletnya
# Processing Record 49 of Set 14 | rawson
# Processing Record 50 of Set 14 | hambantota
# Processing Record 1 of Set 15 | iberia
# Processing Record 2 of Set 15 | zyryanka
# Processing Record 3 of Set 15 | nileshwar
# Processing Record 4 of Set 15 | abu dhabi
# Processing Record 5 of Set 15 | hamilton
# Processing Record 6 of Set 15 | mezhdurechensk
# Processing Record 7 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 15 | turka
# Processing Record 9 of Set 15 | denpasar
# Processing Record 10 of Set 15 | constitucion
# Processing Record 11 of Set 15 | asfi
# Processing Record 12 of Set 15 | killybegs
# Processing Record 13 of Set 15 | margate
# Processing Record 14 of Set 15 | qaqortoq
# Processing Record 15 of Set 15 | letka
# Processing Record 16 of Set 15 | lenger
# Processing Record 17 of Set 15 | sangar
# Processing Record 18 of Set 15 | bridlington
# Processing Record 19 of Set 15 | oistins
# Processing Record 20 of Set 15 | alappuzha
# Processing Record 21 of Set 15 | druzhba
# Processing Record 22 of Set 15 | itoman
# Processing Record 23 of Set 15 | misawa
# Processing Record 24 of Set 15 | ayer itam
# City not found. Skipping...
# Processing Record 25 of Set 15 | aykhal
# Processing Record 26 of Set 15 | paamiut
# Processing Record 27 of Set 15 | kurchum
# Processing Record 28 of Set 15 | uryupinsk
# Processing Record 29 of Set 15 | cristalina
# Processing Record 30 of Set 15 | tromso
# Processing Record 31 of Set 15 | san ramon
# Processing Record 32 of Set 15 | batagay-alyta
# Processing Record 33 of Set 15 | kazminskoye
# City not found. Skipping...
# Processing Record 34 of Set 15 | kutum
# Processing Record 35 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 15 | smolyaninovo
# Processing Record 37 of Set 15 | kamaishi
# Processing Record 38 of Set 15 | langsa
# Processing Record 39 of Set 15 | aquiraz
# Processing Record 40 of Set 15 | katastarion
# Processing Record 41 of Set 15 | hamadan
# Processing Record 42 of Set 15 | gigmoto
# Processing Record 43 of Set 15 | mayo
# Processing Record 44 of Set 15 | dunedin
# Processing Record 45 of Set 15 | rehoboth
# Processing Record 46 of Set 15 | coquimbo
# Processing Record 47 of Set 15 | esna
# Processing Record 48 of Set 15 | irricana
# Processing Record 49 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 15 | aljezur
# Processing Record 1 of Set 16 | sambava
# Processing Record 2 of Set 16 | kudahuvadhoo
# Processing Record 3 of Set 16 | barabinsk
# Processing Record 4 of Set 16 | winton
# Processing Record 5 of Set 16 | virginia beach
# Processing Record 6 of Set 16 | hirado
# Processing Record 7 of Set 16 | vila do maio
# Processing Record 8 of Set 16 | kyabe
# Processing Record 9 of Set 16 | port macquarie
# Processing Record 10 of Set 16 | marawi
# Processing Record 11 of Set 16 | saint george
# Processing Record 12 of Set 16 | claresholm
# Processing Record 13 of Set 16 | diamantino
# Processing Record 14 of Set 16 | ozernovskiy
# Processing Record 15 of Set 16 | coahuayana
# Processing Record 16 of Set 16 | yingkou
# Processing Record 17 of Set 16 | milton
# Processing Record 18 of Set 16 | banikoara
# Processing Record 19 of Set 16 | pangkalanbuun
# Processing Record 20 of Set 16 | galesong
# Processing Record 21 of Set 16 | shizukuishi
# Processing Record 22 of Set 16 | trincomalee
# Processing Record 23 of Set 16 | inverell
# Processing Record 24 of Set 16 | hare bay
# Processing Record 25 of Set 16 | kanniyakumari
# Processing Record 26 of Set 16 | scalea
# Processing Record 27 of Set 16 | appiano
# City not found. Skipping...
# Processing Record 28 of Set 16 | brewster
# Processing Record 29 of Set 16 | portales
# Processing Record 30 of Set 16 | haicheng
# Processing Record 31 of Set 16 | el wasta
# City not found. Skipping...
# Processing Record 32 of Set 16 | palembang
# Processing Record 33 of Set 16 | dicabisagan
# Processing Record 34 of Set 16 | gemena
# Processing Record 35 of Set 16 | surt
# Processing Record 36 of Set 16 | vila franca do campo
# Processing Record 37 of Set 16 | zheleznodorozhnyy
# Processing Record 38 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 16 | kungurtug
# Processing Record 40 of Set 16 | barcelos
# Processing Record 41 of Set 16 | mildura
# Processing Record 42 of Set 16 | fairfield
# Processing Record 43 of Set 16 | inirida
# Processing Record 44 of Set 16 | apollonia
# Processing Record 45 of Set 16 | lorengau
# Processing Record 46 of Set 16 | kaarst
# Processing Record 47 of Set 16 | atambua
# Processing Record 48 of Set 16 | purna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a dataframe from the new city data
city_data_df = pd.DataFrame(city_data)

# %%
# Dropped the Date Column
city_data_df.drop("Date", axis=1, inplace=True)

# %%
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Norman Wells      CA  65.2820 -126.8329      3.67        81         100
# 1         Aklavik      CA  68.2191 -135.0107     -5.98        84          98
# 2      Butaritari      KI   3.0707  172.7902     81.55        78          61
# 3            Lasa      IT  46.6166   10.7002     27.70        94          95
# 4          Burnie      AU -41.0667  145.9167     55.92        62          73
# ..            ...     ...      ...       ...       ...       ...         ...
# 732     Apollonia      GR  36.9716   24.7231     58.59        78           0
# 733      Lorengau      PG  -2.0226  147.2712     80.24        81         100
# 734        Kaarst      DE  51.2333    6.6167     38.01        71         100
# 735       Atambua      ID  -9.1061  124.8925     73.33        76          36
# 736         Purna      IN  19.1833   77.0500     84.58        27          14
#
#      Wind Speed Current Description
# 0          4.05     overcast clouds
# 1          3.24     overcast clouds
# 2         16.06       broken clouds
# 3          6.44     overcast clouds
# 4          8.59       broken clouds
# ..          ...                 ...
# 732       26.46           clear sky
# 733        3.78     overcast clouds
# 734       10.00     overcast clouds
# 735        2.13    scattered clouds
# 736        4.47          few clouds
#
# [737 rows x 9 columns]

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv('weather_database/WeatherPy_Database.csv', index_label="City_ID")
